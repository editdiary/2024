# %% [markdown]
# # Case1 (Case1_sub.csv)
# > Public Score
# > - Case1_sub: 25746.14746

# %%
import sys, os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# column 보기 30개로 설정
pd.set_option('display.max_columns', 30)

# %%
# 데이터 경로 설정
file_path = os.path.join(os.getcwd(), 'data')
train_origin = pd.read_csv(file_path+'\dataset.csv')
test_origin = pd.read_csv(file_path+'\problem.csv')

# %%
train_origin.shape, test_origin.shape
# Out:
# ((1340, 24), (130, 23))

# %%
# 전처리를 위한 원본 데이터 복사
train = train_origin.copy()
test = test_origin.copy()

# %%
# 메모리를 효율적으로 사용하기 위한 downcast 함수 정의
def downcast(df, verbose=True):     # verbose 옵션 추가: (True)인 경우 몇 퍼센트 압축됐는지 출력
    start_mem = df.memory_usage().sum() / 1024**2   # 초기 메모리 사용량
    for col in df.columns:
        dtype_name = df[col].dtype.name
        if dtype_name == 'object':
            pass
        elif dtype_name == 'bool':
            df[col] = df[col].astype('int8')
        elif dtype_name.startswith('int') or (df[col].round() == df[col]).all():
            df[col] = pd.to_numeric(df[col], downcast='integer')
        else:
            df[col] = pd.to_numeric(df[col], downcast='float')
    end_mem = df.memory_usage().sum() / 1024**2

    if verbose:
        print(f'{(100*(start_mem - end_mem) / start_mem):.1f}% 압축됨')

    return df

# %%
downcast(train)
downcast(test)
# Out:
# 67.2% 압축됨
# 68.7% 압축됨
#        Id  LotArea Street LotConfig  OverallQual  OverallCond  YearBuilt  \
# 0    1341    11200   Pave    Inside            5            5       1965
# 1    1342     7200   Pave    Corner            5            7       1951
# 2    1343    16905   Pave    Inside            5            6       1959
# 3    1344     9180   Pave   CulDSac            5            7       1983
# 4    1345     7200   Pave    Inside            5            7       1920
# ..    ...      ...    ...       ...          ...          ...        ...
# 125  1466    11478   Pave    Inside            8            5       2007
# 126  1467    16321   Pave   CulDSac            5            6       1957
# 127  1468     6324   Pave    Inside            4            6       1927
# 128  1469     8500   Pave    Inside            4            4       1920
# 129  1470     8544   Pave   CulDSac            5            6       1966
#
#      YearRemodAdd  TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  FullBath  \
# 0            1965         1040      1040         0       1040         1
# 1            2000          900       900         0        900         1
# 2            1959         1350      1328         0       1328         1
# 3            1983          840       884         0        884         1
# 4            1996          530       581       530       1111         1
# ..            ...          ...       ...       ...        ...       ...
# 125          2008         1704      1704         0       1704         2
# 126          1997         1484      1600         0       1600         1
# 127          1950          520       520         0        520         1
# 128          1950          649       649       668       1317         1
# 129          2006         1228      1228         0       1228         1
#
#      HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 0           0             3             1             5           0
# 1           0             3             1             5           0
# 2           1             2             1             5           2
# 3           0             2             1             5           0
# 4           0             3             1             6           0
# ..        ...           ...           ...           ...         ...
# 125         0             3             1             7           1
# 126         0             2             1             6           2
# 127         0             1             1             4           0
# 128         0             3             1             6           0
# 129         1             3             1             6           0
#
#     GarageType  GarageYrBlt  GarageCars  GarageArea  YrSold
# 0       Detchd         1965           1         384    2008
# 1       Detchd         2005           2         576    2010
# 2       Attchd         1959           1         308    2007
# 3       Attchd         1983           2         504    2007
# 4       Detchd         1935           1         288    2007
# ..         ...          ...         ...         ...     ...
# 125     Attchd         2008           3         772    2010
# 126     Attchd         1957           1         319    2006
# 127     Detchd         1920           1         240    2008
# 128     Detchd         1920           1         250    2008
# 129     Attchd         1966           1         271    2008
#
# [130 rows x 23 columns]

# %% [markdown]
# # 전처리

# %% [markdown]
# ### 결측치 처리

# %%
# 최빈값 대체
train['GarageType'].fillna(train['GarageType'].mode()[0], inplace=True)
train['GarageYrBlt'].fillna(train['GarageYrBlt'].mode()[0], inplace=True)

# %%
train.isnull().sum().sum(), test.isnull().sum().sum()
# Out:
# (0, 0)

# %% [markdown]
# ### Feature engineering

# %%
# 2010년을 기준으로 건물이 지어진 후 지난 시간(연)
train['YearBuiltDiff'] = 2010 - train['YearBuilt']
test['YearBuiltDiff'] = 2010 - test['YearBuilt']

# %%
# 리모델링 후 지난 시간(연)
train['RemodAddDiff'] = 2010 - train['YearRemodAdd']
test['RemodAddDiff'] = 2010 - test['YearRemodAdd']

# %%
# 욕실 수 합치기
train['TotalBath'] = train['FullBath'] + train['HalfBath']
test['TotalBath'] = test['FullBath'] + test['HalfBath']

# %%
# 총 면적
train['TotalSF'] = train['GrLivArea'] + train['TotalBsmtSF']
test['TotalSF'] = test['GrLivArea'] + test['TotalBsmtSF']

# %%
# 2층 여부
train['Has2ndFlr'] = train['2ndFlrSF'].apply(lambda x: 1 if x > 0 else 0)
test['Has2ndFlr'] = test['2ndFlrSF'].apply(lambda x: 1 if x > 0 else 0)

# %%
# 지하실 여부
train['HasBsmt'] = train['TotalBsmtSF'].apply(lambda x: 1 if x > 0 else 0)
test['HasBsmt'] = test['TotalBsmtSF'].apply(lambda x: 1 if x > 0 else 0)

# %%
# 상관계수 히트맵
numeric_data = train.select_dtypes(exclude="object")   # 수치형 데이터만 추출
plt.figure(figsize=(20, 15))
#mask = np.zeros_like(numeric_data.corr(), dtype=np.bool_)
#mask[np.triu_indices_from(mask)] = True     # triu_indices_from: 대각선을 기준으로 위쪽 삼각형만 True로 설정
sns.heatmap(numeric_data.corr(), annot=True, fmt='.2f', cmap='RdBu')    # cmap: 색상  # 절반만 표시하고 싶은 경우 mask=mask 옵션 추가
plt.show()

# %% [markdown]
# ### 일부 feature 제거

# %%
train.columns
# Out:
# Index(['LotArea', 'Street', 'LotConfig', 'OverallQual', 'OverallCond',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageType', 'GarageCars', 'SalePrice', 'YearBuiltDiff',
#        'RemodAddDiff', 'TotalBath', 'TotalSF', 'Has2ndFlr', 'HasBsmt'],
#       dtype='object')

# %%
no_use_features = ['Id', 'YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold', 'GarageArea', 'TotalBsmtSF', 'GrLivArea', '1stFlrSF', '2ndFlrSF', 'FullBath', 'HalfBath']

# %%
train.drop(no_use_features, axis=1, inplace=True)
test.drop(no_use_features, axis=1, inplace=True)

# %% [markdown]
# ### 중복 데이터 제거

# %%
train.duplicated().sum()    # 중복 데이터 확인
# Out:
# 2

# %%
train = train.drop_duplicates()     # 중복 데이터 제거

# %% [markdown]
# ### 이상치 처리
# > target 값인 SalePrice와 그와 상관관계가 매우 높은 몇 가지 feature만 이상치 처리를 좀 해주자.

# %% [markdown]
# > GrLivArea

# %%
# GrLivArea와 SalePrice scatterplot
plt.figure(figsize=(8, 8))
sns.scatterplot(data=train, x='GrLivArea', y='SalePrice')
plt.show()

# %%
# 이상치 제거
outlier_index = train[(train['SalePrice']<220000)&(train['GrLivArea']>4000)]
train = train.drop(outlier_index.index).reset_index(drop=True)

# %% [markdown]
# > TotalBsmtSF

# %%
# OverallQual과 SalePrice scatterplot
plt.figure(figsize=(8, 8))
sns.scatterplot(data=train, x='TotalBsmtSF', y='SalePrice')
plt.show()

# %% [markdown]
# > LotArea 이상치 제거

# %%
sns.boxplot(train['LotArea'])
# Out:
# <Axes: ylabel='LotArea'>

# %%
# LotArea 이상치 제거
train = train[train['LotArea'] < 100000].reset_index(drop=True)

# %% [markdown]
# ### Encoding

# %%
# X, y 분리
X_train = train.drop(columns='SalePrice', axis=1)
y_train = train['SalePrice']

# %%
all_data = pd.concat([X_train, test], axis=0).reset_index(drop=True)

# %%
all_data
# Out:
#       LotArea Street LotConfig  OverallQual  OverallCond  TotalBsmtSF  \
# 0        8450   Pave    Inside            7            5          856
# 1        9600   Pave       FR2            6            8         1262
# 2       11250   Pave    Inside            7            5          920
# 3        9550   Pave    Corner            7            5          756
# 4       14260   Pave       FR2            8            5         1145
# ...       ...    ...       ...          ...          ...          ...
# 1458    11478   Pave    Inside            8            5         1704
# 1459    16321   Pave   CulDSac            5            6         1484
# 1460     6324   Pave    Inside            4            6          520
# 1461     8500   Pave    Inside            4            4          649
# 1462     8544   Pave   CulDSac            5            6         1228
#
#       1stFlrSF  2ndFlrSF  GrLivArea  FullBath  HalfBath  BedroomAbvGr  \
# 0          856       854       1710         2         1             3
# 1         1262         0       1262         2         0             3
# 2          920       866       1786         2         1             3
# 3          961       756       1717         1         0             3
# 4         1145      1053       2198         2         1             4
# ...        ...       ...        ...       ...       ...           ...
# 1458      1704         0       1704         2         0             3
# 1459      1600         0       1600         1         0             2
# 1460       520         0        520         1         0             1
# 1461       649       668       1317         1         0             3
# 1462      1228         0       1228         1         1             3
#
#       KitchenAbvGr  TotRmsAbvGrd  Fireplaces GarageType  GarageCars  \
# 0                1             8           0     Attchd           2
# 1                1             6           1     Attchd           2
# 2                1             6           1     Attchd           2
# 3                1             7           1     Detchd           3
# 4                1             9           1     Attchd           3
# ...            ...           ...         ...        ...         ...
# 1458             1             7           1     Attchd           3
# 1459             1             6           2     Attchd           1
# 1460             1             4           0     Detchd           1
# 1461             1             6           0     Detchd           1
# 1462             1             6           0     Attchd           1
#
#       YearBuiltDiff  RemodAddDiff  TotalBath  TotalSF  Has2ndFlr  HasBsmt
# 0                 7             7          3     2566          1        1
# 1                34            34          2     2524          0        1
# 2                 9             8          3     2706          1        1
# 3                95            40          1     2473          1        1
# 4                10            10          3     3343          1        1
# ...             ...           ...        ...      ...        ...      ...
# 1458              3             2          2     3408          0        1
# 1459             53            13          1     3084          0        1
# 1460             83            60          1     1040          0        1
# 1461             90            60          1     1966          1        1
# 1462             44             4          2     2456          0        1
#
# [1463 rows x 23 columns]

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

categorical = all_data.select_dtypes(include='object').columns

for feature in categorical:
    all_data[feature] = encoder.fit_transform(all_data[feature])

# %%
all_data
# Out:
#       LotArea  Street  LotConfig  OverallQual  OverallCond  TotalBsmtSF  \
# 0        8450       1          4            7            5          856
# 1        9600       1          2            6            8         1262
# 2       11250       1          4            7            5          920
# 3        9550       1          0            7            5          756
# 4       14260       1          2            8            5         1145
# ...       ...     ...        ...          ...          ...          ...
# 1458    11478       1          4            8            5         1704
# 1459    16321       1          1            5            6         1484
# 1460     6324       1          4            4            6          520
# 1461     8500       1          4            4            4          649
# 1462     8544       1          1            5            6         1228
#
#       1stFlrSF  2ndFlrSF  GrLivArea  FullBath  HalfBath  BedroomAbvGr  \
# 0          856       854       1710         2         1             3
# 1         1262         0       1262         2         0             3
# 2          920       866       1786         2         1             3
# 3          961       756       1717         1         0             3
# 4         1145      1053       2198         2         1             4
# ...        ...       ...        ...       ...       ...           ...
# 1458      1704         0       1704         2         0             3
# 1459      1600         0       1600         1         0             2
# 1460       520         0        520         1         0             1
# 1461       649       668       1317         1         0             3
# 1462      1228         0       1228         1         1             3
#
#       KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  YearBuiltDiff  \
# 0                1             8           0           2              7
# 1                1             6           1           2             34
# 2                1             6           1           2              9
# 3                1             7           1           3             95
# 4                1             9           1           3             10
# ...            ...           ...         ...         ...            ...
# 1458             1             7           1           3              3
# 1459             1             6           2           1             53
# 1460             1             4           0           1             83
# 1461             1             6           0           1             90
# 1462             1             6           0           1             44
#
#       RemodAddDiff  TotalBath  TotalSF  Has2ndFlr  HasBsmt  GarageType_2Types  \
# 0                7          3     2566          1        1              False
# 1               34          2     2524          0        1              False
# 2                8          3     2706          1        1              False
# 3               40          1     2473          1        1              False
# 4               10          3     3343          1        1              False
# ...            ...        ...      ...        ...      ...                ...
# 1458             2          2     3408          0        1              False
# 1459            13          1     3084          0        1              False
# 1460            60          1     1040          0        1              False
# 1461            60          1     1966          1        1              False
# 1462             4          2     2456          0        1              False
#
#       GarageType_Attchd  GarageType_Basment  GarageType_BuiltIn  \
# 0                  True               False               False
# 1                  True               False               False
# 2                  True               False               False
# 3                 False               False               False
# 4                  True               False               False
# ...                 ...                 ...                 ...
# 1458               True               False               False
# 1459               True               False               False
# 1460              False               False               False
# 1461              False               False               False
# 1462               True               False               False
#
#       GarageType_CarPort  GarageType_Detchd
# 0                  False              False
# 1                  False              False
# 2                  False              False
# 3                  False               True
# 4                  False              False
# ...                  ...                ...
# 1458               False              False
# 1459               False              False
# 1460               False               True
# 1461               False               True
# 1462               False              False
#
# [1463 rows x 28 columns]

# %%
# 공통 전처리 끝
X_train = all_data.iloc[:len(X_train)]
test = all_data.iloc[len(X_train):].reset_index(drop=True)

# %%
X_train.shape, test.shape
# Out:
# ((1333, 28), (130, 28))

# %%
X_train.loc[:, 'LotArea'] = np.log1p(X_train['LotArea'])
test.loc[:, 'LotArea'] = np.log1p(test['LotArea'])

X_train.loc[:, 'GrLivArea'] = np.log1p(X_train['GrLivArea'])
test.loc[:, 'GrLivArea'] = np.log1p(test['GrLivArea'])

# %%
# # 수치형 변수들 Robust Scaling
# from sklearn.preprocessing import RobustScaler

# scaler = RobustScaler().fit(X_train)

# X_train = scaler.transform(X_train)
# test = scaler.transform(test)

# %%
X_train
# Out:
#        LotArea  Street  LotConfig  OverallQual  OverallCond  TotalBsmtSF  \
# 0     9.042040       1          4            7            5          856
# 1     9.169623       1          2            6            8         1262
# 2     9.328212       1          4            7            5          920
# 3     9.164401       1          0            7            5          756
# 4     9.565284       1          2            8            5         1145
# ...        ...     ...        ...          ...          ...          ...
# 1328  8.976894       1          4            6            5          953
# 1329  9.486152       1          4            6            6         1542
# 1330  9.109746       1          4            7            9         1152
# 1331  9.181735       1          4            5            6         1078
# 1332  9.204121       1          4            5            6         1256
#
#       1stFlrSF  2ndFlrSF  GrLivArea  FullBath  HalfBath  BedroomAbvGr  \
# 0          856       854   7.444833         2         1             3
# 1         1262         0   7.141245         2         0             3
# 2          920       866   7.488294         2         1             3
# 3          961       756   7.448916         1         0             3
# 4         1145      1053   7.695758         2         1             4
# ...        ...       ...        ...       ...       ...           ...
# 1328       953       694   7.407318         2         1             3
# 1329      2073         0   7.637234         2         0             3
# 1330      1188      1152   7.758334         2         0             4
# 1331      1078         0   6.983790         1         0             2
# 1332      1256         0   7.136483         1         1             3
#
#       KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  YearBuiltDiff  \
# 0                1             8           0           2              7
# 1                1             6           1           2             34
# 2                1             6           1           2              9
# 3                1             7           1           3             95
# 4                1             9           1           3             10
# ...            ...           ...         ...         ...            ...
# 1328             1             7           1           2             11
# 1329             1             7           2           2             32
# 1330             1             9           2           1             69
# 1331             1             5           0           1             60
# 1332             1             6           0           1             45
#
#       RemodAddDiff  TotalBath  TotalSF  Has2ndFlr  HasBsmt  GarageType_2Types  \
# 0                7          3     2566          1        1              False
# 1               34          2     2524          0        1              False
# 2                8          3     2706          1        1              False
# 3               40          1     2473          1        1              False
# 4               10          3     3343          1        1              False
# ...            ...        ...      ...        ...      ...                ...
# 1328            10          3     2600          1        1              False
# 1329            22          2     3615          0        1              False
# 1330             4          2     3492          1        1              False
# 1331            14          1     2156          0        1              False
# 1332            45          2     2512          0        1              False
#
#       GarageType_Attchd  GarageType_Basment  GarageType_BuiltIn  \
# 0                  True               False               False
# 1                  True               False               False
# 2                  True               False               False
# 3                 False               False               False
# 4                  True               False               False
# ...                 ...                 ...                 ...
# 1328               True               False               False
# 1329               True               False               False
# 1330               True               False               False
# 1331               True               False               False
# 1332               True               False               False
#
#       GarageType_CarPort  GarageType_Detchd
# 0                  False              False
# 1                  False              False
# 2                  False              False
# 3                  False               True
# 4                  False              False
# ...                  ...                ...
# 1328               False              False
# 1329               False              False
# 1330               False              False
# 1331               False              False
# 1332               False              False
#
# [1333 rows x 28 columns]

# %%
test
# Out:
#       LotArea  Street  LotConfig  OverallQual  OverallCond  TotalBsmtSF  \
# 0    9.323758       1          4            5            5         1040
# 1    8.881975       1          0            5            7          900
# 2    9.735424       1          4            5            6         1350
# 3    9.124891       1          1            5            7          840
# 4    8.881975       1          4            5            7          530
# ..        ...     ...        ...          ...          ...          ...
# 125  9.348275       1          4            8            5         1704
# 126  9.700269       1          1            5            6         1484
# 127  8.752265       1          4            4            6          520
# 128  9.047939       1          4            4            4          649
# 129  9.053102       1          1            5            6         1228
#
#      1stFlrSF  2ndFlrSF  GrLivArea  FullBath  HalfBath  BedroomAbvGr  \
# 0        1040         0   6.947937         1         0             3
# 1         900         0   6.803505         1         0             3
# 2        1328         0   7.192182         1         1             2
# 3         884         0   6.785588         1         0             2
# 4         581       530   7.013916         1         0             3
# ..        ...       ...        ...       ...       ...           ...
# 125      1704         0   7.441320         2         0             3
# 126      1600         0   7.378384         1         0             2
# 127       520         0   6.255750         1         0             1
# 128       649       668   7.183871         1         0             3
# 129      1228         0   7.113956         1         1             3
#
#      KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  YearBuiltDiff  \
# 0               1             5           0           1             45
# 1               1             5           0           2             59
# 2               1             5           2           1             51
# 3               1             5           0           2             27
# 4               1             6           0           1             90
# ..            ...           ...         ...         ...            ...
# 125             1             7           1           3              3
# 126             1             6           2           1             53
# 127             1             4           0           1             83
# 128             1             6           0           1             90
# 129             1             6           0           1             44
#
#      RemodAddDiff  TotalBath  TotalSF  Has2ndFlr  HasBsmt  GarageType_2Types  \
# 0              45          1     2080          0        1              False
# 1              10          1     1800          0        1              False
# 2              51          2     2678          0        1              False
# 3              27          1     1724          0        1              False
# 4              14          1     1641          1        1              False
# ..            ...        ...      ...        ...      ...                ...
# 125             2          2     3408          0        1              False
# 126            13          1     3084          0        1              False
# 127            60          1     1040          0        1              False
# 128            60          1     1966          1        1              False
# 129             4          2     2456          0        1              False
#
#      GarageType_Attchd  GarageType_Basment  GarageType_BuiltIn  \
# 0                False               False               False
# 1                False               False               False
# 2                 True               False               False
# 3                 True               False               False
# 4                False               False               False
# ..                 ...                 ...                 ...
# 125               True               False               False
# 126               True               False               False
# 127              False               False               False
# 128              False               False               False
# 129               True               False               False
#
#      GarageType_CarPort  GarageType_Detchd
# 0                 False               True
# 1                 False               True
# 2                 False              False
# 3                 False              False
# 4                 False               True
# ..                  ...                ...
# 125               False              False
# 126               False              False
# 127               False               True
# 128               False               True
# 129               False              False
#
# [130 rows x 28 columns]

# %% [markdown]
# # Model training

# %% [markdown]
# ### XGBoost

# %%
# 베이지안 최적화
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor

def rmse_cv(model):
    rmse = np.sqrt(-cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=10))
    return rmse, rmse.mean()

param_bounds = {
    'learning_rate' : (0.001, 0.5),
    'max_leaves': (2, 1024),
    'n_estimators': (100, 1000),
    'gamma': (0, 10),
    'max_depth': (3, 15),
    'min_child_weight': (1, 20),
    }

def eval_function(max_leaves, learning_rate, n_estimators, gamma, max_depth, min_child_weight):
    params = {
        'learning_rate' : learning_rate, 
        'max_leaves': int(max_leaves),
        'n_estimators': int(n_estimators),
        'gamma': gamma,
        'max_depth': int(max_depth),
        'min_child_weight': min_child_weight,
    }

    xgb_model = XGBRegressor(**params, random_state=42)
    score, mean_score = rmse_cv(xgb_model)
    return -mean_score

# %%
from bayes_opt import BayesianOptimization

optimizer = BayesianOptimization(f=eval_function, pbounds=param_bounds, random_state=42)
optimizer.maximize(init_points=5, n_iter=10)
# Out:
# |   iter    |  target   |   gamma   | learni... | max_depth | max_le... | min_ch... | n_esti... |
# -------------------------------------------------------------------------------------------------
# | 1         | -2.9e+04  | 3.745     | 0.4754    | 11.78     | 613.8     | 3.964     | 240.4     |
# | 2         | -2.827e+0 | 0.5808    | 0.4332    | 10.21     | 725.7     | 1.391     | 972.9     |
# | 3         | -2.558e+0 | 8.324     | 0.107     | 5.182     | 189.4     | 6.781     | 572.3     |
# | 4         | -2.662e+0 | 4.319     | 0.1463    | 10.34     | 144.6     | 6.551     | 429.7     |
# | 5         | -2.742e+0 | 4.561     | 0.3928    | 5.396     | 527.5     | 12.26     | 141.8     |
# | 6         | -2.855e+0 | 1.683     | 0.4184    | 9.587     | 195.4     | 14.69     | 560.0     |
# | 7         | -2.741e+0 | 1.242     | 0.3566    | 11.89     | 161.9     | 13.04     | 896.4     |
# | 8         | -2.837e+0 | 2.104     | 0.4963    | 5.567     | 718.5     | 10.42     | 358.9     |
# | 9         | -2.726e+0 | 7.896     | 0.2682    | 13.74     | 469.4     | 9.027     | 688.4     |
# | 10        | -2.573e+0 | 4.378     | 0.08155   | 4.683     | 3.549     | 19.96     | 579.5     |
# | 11        | -2.7e+04  | 2.79      | 0.07925   | 9.715     | 146.5     | 2.644     | 432.3     |
# | 12        | -2.666e+0 | 9.909     | 0.07949   | 10.73     | 4.597     | 16.78     | 584.7     |
# | 13        | -2.687e+0 | 5.785     | 0.171     | 8.743     | 190.8     | 6.372     | 582.5     |
# | 14        | -2.583e+0 | 3.117     | 0.1603    | 3.098     | 10.93     | 17.97     | 578.5     |
# | 15        | -2.543e+0 | 7.074     | 0.06243   | 3.097     | 179.0     | 3.014     | 574.6     |
# =================================================================================================

# %%
# 최적화된 하이퍼파라미터로 모델 재학습
best_params = {
    'n_estimators': round(optimizer.max['params']['n_estimators']),
    'max_depth': round(optimizer.max['params']['max_depth']),
    'max_leaves': round(optimizer.max['params']['max_leaves']),
    'min_child_weight': round(optimizer.max['params']['min_child_weight']),
    'learning_rate': optimizer.max['params']['learning_rate'],
    'gamma': optimizer.max['params']['gamma'],
}

best_xgb = XGBRegressor(**best_params, random_state=42)
score, mean_score = rmse_cv(best_xgb)
print(score)
print(mean_score)
# Out:
# [22905.03242352 22444.87506822 24978.37213448 28862.27321647
#  34956.6574697  25161.59017601 25545.79694678 20865.27441011
#  24462.9228501  24438.56262115]
# 25462.135731654453

# %%
# 모델의 결정계수 확인
from sklearn.metrics import r2_score

best_xgb = XGBRegressor(**best_params, random_state=42)
best_xgb.fit(X_train, y_train)
y_pred = best_xgb.predict(X_train)

r2_score(y_pred, y_train)
# Out:
# 0.9728200358133743

# %% [markdown]
# # 결과 제출

# %%
# submission 파일 생성
submission_origin = pd.read_csv(file_path+'\submission.csv')
submission = submission_origin.copy()

# %%
# 최종 모델(XGBRegressor)로 test set 예측
xgb_pred = best_xgb.predict(test)

submission['SalePrice'] = xgb_pred
submission.to_csv('Case1_sub.csv', index=False)
